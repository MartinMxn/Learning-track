# %%
import numpy as np

# %%
import pandas as pd
# %matplotlib inline

# %%
#Read in both parts of the Titanic dataset
my_df_1 = pd.read_csv("/Users/xuanningmeng/Desktop/6105DS/Module1/Titanic.csv")
my_df_2 = pd.read_csv("/Users/xuanningmeng/Desktop/6105DS/Module1/Titanic_II.csv")

print(my_df_1.shape)
print(my_df_2.shape)
# Out:
# (891, 12)
# (418, 12)

# %%
my_df_2.shape
# Out:
# (418, 12)

# %%
# Get column names of your dataframe

print(my_df_1.columns)
print(my_df_2.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Merge the two dataframes into the same dataframe using append

merged_df = my_df_1.append(my_df_2)
merged_df.shape
# Out:
# (1309, 12)

# %%
#Merge the two dataframes into the same dataframe using concat

df_list = [my_df_1,my_df_2]
merged_df_2 = pd.concat(df_list, axis = 0)
merged_df_2.shape
# Out:
# (1309, 12)

# %%
# Write out the merged dataframe as a .csv file

merged_df.to_csv("/Users/xuanningmeng/Desktop/6105DS/Module1/merged_data.csv",index = False)

# %%
# How can we define our own function and make new columns with derived data

def child_age(x):
    if x < 12:
        return "Child"
    elif x>12:
        return "Adult"
    else:
        return "unknown"

merged_df["Status"] = merged_df["Age"].apply(child_age)

merged_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Status
# 0      0         A/5 21171   7.2500   NaN        S  Adult
# 1      0          PC 17599  71.2833   C85        C  Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Adult
# 3      0            113803  53.1000  C123        S  Adult
# 4      0            373450   8.0500   NaN        S  Adult

# %%
merged_df[["Age","Status"]].head(n = 9)
# Out:
#     Age   Status
# 0  22.0    Adult
# 1  38.0    Adult
# 2  26.0    Adult
# 3  35.0    Adult
# 4  35.0    Adult
# 5   NaN  unknown
# 6  54.0    Adult
# 7   2.0    Child
# 8  27.0    Adult

# %%
# How to make summary statistics of a column
merged_df["Fare"].describe()
# Out:
# count    1308.000000
# mean       33.295479
# std        51.758668
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: Fare, dtype: float64

# %%
# Make a dataframe by joining lists of data

Names = ["Jason","Laura","Johnson","Meuller","Anna"]

City = ["Seattle","San Francisco", "Portland", "Santa Cruz", "Athens"]

State = ["Washington", "California", "Oregon", "California", "Georgia"]

Income = [70000,80000,105000,45000,90000]

our_df = pd.DataFrame({"Name": Names, "City": City, 
                       "State": State, "Annual Income": Income})

our_df.head()
# Out:
#       Name           City       State  Annual Income
# 0    Jason        Seattle  Washington          70000
# 1    Laura  San Francisco  California          80000
# 2  Johnson       Portland      Oregon         105000
# 3  Meuller     Santa Cruz  California          45000
# 4     Anna         Athens     Georgia          90000

# %%
# Find and replace in our dataframe

rep_df = our_df.replace(to_replace = "California",
                        value = "CA",inplace = False)

rep_df.head()
# Out:
#       Name           City       State  Annual Income
# 0    Jason        Seattle  Washington          70000
# 1    Laura  San Francisco          CA          80000
# 2  Johnson       Portland      Oregon         105000
# 3  Meuller     Santa Cruz          CA          45000
# 4     Anna         Athens     Georgia          90000

# %%
our_df.head()
# Out:
#       Name           City       State  Annual Income
# 0    Jason        Seattle  Washington          70000
# 1    Laura  San Francisco  California          80000
# 2  Johnson       Portland      Oregon         105000
# 3  Meuller     Santa Cruz  California          45000
# 4     Anna         Athens     Georgia          90000

# %%
rep_df.plot(x = "City", y = "Annual Income", kind = "line")

# %% [markdown]
# # Drill Time !

# %% [markdown]
# Write a function that takes as input the fare, and if it's below 10, outputs "inexpensive", and if it's above 10 returns "expensive". Use this function to add a new column "Fare status" to your dataframe

# %%
def add_fare(x):
    if x < 10:
        return "inexpensive"
    else:
        return "expensive"

merged_df["Fare status"] = merged_df["Fare"].apply(add_fare)

merged_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Status  Fare status
# 0      0         A/5 21171   7.2500   NaN        S  Adult  inexpensive
# 1      0          PC 17599  71.2833   C85        C  Adult    expensive
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Adult  inexpensive
# 3      0            113803  53.1000  C123        S  Adult    expensive
# 4      0            373450   8.0500   NaN        S  Adult  inexpensive

# %% [markdown]
# Get all column names of your new dataframe

# %%
merged_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Status',
#        'Fare status'],
#       dtype='object')

# %% [markdown]
# Write this dataframe to disk as a csv file

# %%
merged_df.to_csv("/Users/xuanningmeng/Desktop/6105DS/Module1/exercise2.csv")

# %% [markdown]
# Calculate summary statistics for the age column of your dataframe. What is the mean age ?

# %%
merged_df["Age"].describe()
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# What is the average age of passengers who travelled first class ?

# %%
fc_dc = merged_df[merged_df["Pclass"] == 1]
fc_dc["Age"].describe()
# Out:
# count    284.000000
# mean      39.159930
# std       14.548028
# min        0.920000
# 25%       28.000000
# 50%       39.000000
# 75%       50.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# What is the average fare paid by passengers who travelled first class ?

# %%
fc_dc["Fare"].describe()
# Out:
# count    323.000000
# mean      87.508992
# std       80.447178
# min        0.000000
# 25%       30.695800
# 50%       60.000000
# 75%      107.662500
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# Replace male by M and female by F in the dataframe

# %%
rp_df = merged_df.replace(to_replace = "female", value = "F",inplace = False)
rp_df = rp_df.replace(to_replace = "male", value = "M",inplace = False)
rp_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   M  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1      0
# 2                             Heikkinen, Miss. Laina   F  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1      0
# 4                           Allen, Mr. William Henry   M  35.0      0      0
#
#              Ticket     Fare Cabin Embarked Status  Fare status
# 0         A/5 21171   7.2500   NaN        S  Adult  inexpensive
# 1          PC 17599  71.2833   C85        C  Adult    expensive
# 2  STON/O2. 3101282   7.9250   NaN        S  Adult  inexpensive
# 3            113803  53.1000  C123        S  Adult    expensive
# 4            373450   8.0500   NaN        S  Adult  inexpensive

# %% [markdown]
# Scatter plot fares against passenger Age

# %%
merged_df.plot(x = "Name", y = "Fare", kind = "bar", figsize = (20,10))
